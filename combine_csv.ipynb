# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# path variables for KEVIN

path = "D:\Kevin Liang/Documents/1_UT_SENIOR/UT_AUSTIN_FALL_2017/EE_379K/Data_Science_Final_Project/Kickstarter_Data/"

# %%
combined_data = pd.DataFrame()

for x in range(40):
    if x == 0:
        data = pd.read_csv(path + "Kickstarter.csv", header = 0, index_col = 0)
    else:
        data = pd.read_csv(path + "Kickstarter" + str(x).zfill(3) + ".csv", header = 0,index_col = 0)
    
    dropped_features = ["slug", "state_changed_at", "currency_symbol", "permissions", "is_backing", "is_starred", "friends","staff_pick","backers_count","spotlight","profile","static_usd_rate"]
    data = data.drop(dropped_features, axis = 1)
    combined_data = combined_data.append(data, ignore_index = True)
    
print combined_data
# Out:
#                                                     photo  \
# 0       {"small":"https://ksr-ugc.imgix.net/assets/013...
# 1       {"small":"https://ksr-ugc.imgix.net/assets/014...
# 2       {"small":"https://ksr-ugc.imgix.net/assets/014...
# 3       {"small":"https://ksr-ugc.imgix.net/assets/014...
# 4       {"small":"https://ksr-ugc.imgix.net/assets/014...
# 5       {"small":"https://ksr-ugc.imgix.net/assets/014...
# 6       {"small":"https://ksr-ugc.imgix.net/assets/014...
# 7       {"small":"https://ksr-ugc.imgix.net/assets/014...
# 8       {"small":"https://ksr-ugc.imgix.net/assets/014...
# 9       {"small":"https://ksr-ugc.imgix.net/assets/014...
# 10      {"small":"https://ksr-ugc.imgix.net/assets/015...
# 11      {"small":"https://ksr-ugc.imgix.net/assets/015...
# 12      {"small":"https://ksr-ugc.imgix.net/assets/012...
# 13      {"small":"https://ksr-ugc.imgix.net/assets/013...
# 14      {"small":"https://ksr-ugc.imgix.net/assets/013...
# ...

# %%
combined_data.to_csv(path + "combined_data.csv")

# %%
combined_data.shape
# Out:
# (157127, 23)
